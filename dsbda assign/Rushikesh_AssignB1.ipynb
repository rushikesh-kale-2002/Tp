# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv("C:\\Users\\HP\\Desktop\\dataset_Facebook.csv")

# %%
file
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
file.shape
# Out:
# (500, 19)

# %%
file1=file.iloc[[3,5,9,18,20,47,58,60,67],:]

# %%
file1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3             139441   Photo         2          12             2         10
# 5             139441  Status         2          12             1          9
# 9             139441   Photo         3          12             6         10
# 18            138414  Status         3          12             2          3
# 20            138414   Photo         2          12             1          3
# 47            138353    Link         1          12             3          2
# 58            138329   Photo         1          11             4         10
# 60            138185   Photo         1          11             3         11
# 67            138185   Photo         1          11             7          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3    1.0                      50128                            87991
# ...

# %%
file1.shape
# Out:
# (9, 19)

# %%
file2=file.iloc[[80,85,95,97,105,115,123,137,145],:]
file2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 80             137177  Status         2          11             7          3
# 85             137177   Photo         1          11             4          9
# 95             137059   Photo         3          10             6         10
# 97             137059   Photo         2          10             5         11
# 105            137020   Photo         1          10             2          4
# 115            136642   Photo         1          10             7         12
# 123            136393   Photo         1          10             7          7
# 137            136013   Photo         1          10             5          8
# 145            136013   Photo         1          10             1         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 80    0.0                       8728                            17827
# ...

# %%
file2.shape
# Out:
# (9, 19)

# %%
m1=pd.concat([file1, file2])
m1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 9              139441   Photo         3          12             6         10
# 18             138414  Status         3          12             2          3
# 20             138414   Photo         2          12             1          3
# 47             138353    Link         1          12             3          2
# 58             138329   Photo         1          11             4         10
# 60             138185   Photo         1          11             3         11
# 67             138185   Photo         1          11             7          3
# 80             137177  Status         2          11             7          3
# 85             137177   Photo         1          11             4          9
# ...

# %%
m1.shape
# Out:
# (18, 19)

# %%
file3 = file.iloc[:, [2,3,4,7]]
file3
# Out:
#      Category  Post Month  Post Weekday  Lifetime Post Total Reach
# 0           2          12             4                       2752
# 1           2          12             3                      10460
# 2           3          12             3                       2413
# 3           2          12             2                      50128
# 4           2          12             2                       7244
# ..        ...         ...           ...                        ...
# 495         3           1             7                       4684
# 496         2           1             5                       3480
# 497         1           1             5                       3778
# 498         3           1             4                       4156
# 499         2           1             4                       4188
#
# [500 rows x 4 columns]

# %%
file4 = file.iloc[:, [12,15,18]]
file4
# Out:
#      Lifetime Post Impressions by people who have liked your Page  comment  \
# 0                                                 3078                   4
# 1                                                11710                   5
# 2                                                 2812                   0
# 3                                                61027                  58
# 4                                                 6228                  19
# ..                                                 ...                 ...
# 495                                               4750                   5
# 496                                               3961                   0
# 497                                               4742                   4
# 498                                               4534                   7
# 499                                               3861                   0
#
#      Total Interactions
# 0                   100
# ...

# %%
m2 = file3.merge(file4,left_index=True, right_index=True)
m2
# Out:
#      Category  Post Month  Post Weekday  Lifetime Post Total Reach  \
# 0           2          12             4                       2752
# 1           2          12             3                      10460
# 2           3          12             3                       2413
# 3           2          12             2                      50128
# 4           2          12             2                       7244
# ..        ...         ...           ...                        ...
# 495         3           1             7                       4684
# 496         2           1             5                       3480
# 497         1           1             5                       3778
# 498         3           1             4                       4156
# 499         2           1             4                       4188
#
#      Lifetime Post Impressions by people who have liked your Page  comment  \
# 0                                                 3078                   4
# ...

# %%
sort_values = file.sort_values('comment',ascending=False)
sort_values
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
# ..                ...    ...       ...         ...           ...        ...
# 332            119198  Photo         3           5             2         12
# 333            119198  Photo         3           5             2          1
# 111            136736  Photo         1          10             6          8
# 103            137020  Photo         1          10             3          4
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
file.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
reshape = file.melt(id_vars=["like"],value_vars=["share","comment"])
reshape
# Out:
#        like variable  value
# 0      79.0    share   17.0
# 1     130.0    share   29.0
# 2      66.0    share   14.0
# 3    1572.0    share  147.0
# 4     325.0    share   49.0
# ..      ...      ...    ...
# 995    53.0  comment    5.0
# 996    53.0  comment    0.0
# 997    93.0  comment    4.0
# 998    91.0  comment    7.0
# 999    91.0  comment    0.0
#
# [1000 rows x 3 columns]
